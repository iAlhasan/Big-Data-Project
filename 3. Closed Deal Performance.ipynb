# %%
from pyspark.ml.classification import LogisticRegression
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cd =  sqlContext.sql("select * from olist_closed_deals_dataset_csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
order_items = sqlContext.sql("select * from olist_order_items_dataset_csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
orders = sqlContext.sql("select * from olist_orders_dataset_csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
products = sqlContext.sql("select * from olist_products_dataset_csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
product_translation = sqlContext.sql("select * from product_category_name_translation_csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(cd.count(), len(cd.columns))
print(order_items.count(), len(order_items.columns))
print(orders.count(), len(orders.columns))
print(products.count(), len(products.columns))
print(product_translation.count(), len(product_translation.columns))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">842 14
# 112650 7
# 99441 8
# 32951 9
# 71 2
# </div>

# %%
data = cd.join(order_items, on= ['seller_id'], how='inner')
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>seller_id</th><th>mql_id</th><th>sdr_id</th><th>sr_id</th><th>won_date</th><th>business_segment</th><th>lead_type</th><th>lead_behaviour_profile</th><th>has_company</th><th>has_gtin</th><th>average_stock</th><th>business_type</th><th>declared_product_catalog_size</th><th>declared_monthly_revenue</th><th>order_id</th><th>order_item_id</th><th>product_id</th><th>shipping_limit_date</th><th>price</th><th>freight_value</th></tr></thead><tbody><tr><td>ba143b05f0110f0dc71ad71b4466ce92</td><td>cfccca319397a5ea2bb11bd90b0d925d</td><td>370c9f455f93a9a96cbe9bea48e70033</td><td>9e4d1098a3b0f5da39b0bc48f9876645</td><td>2018-04-17 19:12:16</td><td>books</td><td>online_big</td><td>cat</td><td>null</td><td>null</td><td>null</td><td>reseller</td><td>null</td><td>0.0</td><td>0005f50442cb953dcd1d21e1fb923495</td><td>1</td><td>4535b0e1091c278dfd193e5a1d63b39f</td><td>2018-07-06 14:10:56</td><td>53.99</td><td>11.40</td></tr><tr><td>ffc470761de7d0232558ba5e786e57b7</td><td>115f08592f4c2bb29013efbbc46608fc</td><td>4b339f9567d060bcea4f5136b9f5949e</td><td>4ef15afb4b2723d8f3d81e51ec7afefe</td><td>2018-02-14 11:48:29</td><td>construction_tools_house_garden</td><td>online_big</td><td>null</td><td>null</td><td>null</td><td>null</td><td>reseller</td><td>null</td><td>0.0</td><td>001ac194d4a326a6fa99b581e9a3d963</td><td>1</td><td>dbaee28f4ee64465838a229582d77520</td><td>2018-07-10 02:51:10</td><td>54.00</td><td>8.54</td></tr><tr><td>d3dcf0604eabf0224fbd5948b5e02f69</td><td>31aa9651503a33c7f28f2a6e4d46b6e0</td><td>de63de0d10a6012430098db33c679b0b</td><td>4ef15afb4b2723d8f3d81e51ec7afefe</td><td>2018-02-02 11:22:56</td><td>music_instruments</td><td>online_medium</td><td>null</td><td>null</td><td>null</td><td>null</td><td>reseller</td><td>null</td><td>0.0</td><td>0029f17cf0e7640c5cb6825af681303f</td><td>1</td><td>01c666c82f414c762ad21bffa56e8b49</td><td>2018-05-08 12:14:52</td><td>94.90</td><td>18.54</td></tr><tr><td>70c27847eca8195c983ed7e798c56743</td><td>fc4166d1b1e192f650ee2d807b54c943</td><td>fdb16d3cbbeb5798f2f66c4096be026d</td><td>4ef15afb4b2723d8f3d81e51ec7afefe</td><td>2018-02-08 20:57:44</td><td>pet</td><td>online_small</td><td>null</td><td>null</td><td>null</td><td>null</td><td>reseller</td><td>null</td><td>0.0</td><td>00335f75ea6a4455b524a8dd177067f5</td><td>1</td><td>e1bf2f209fd2b08e1af3ed71732d9008</td><td>2018-05-02 22:10:29</td><td>168.80</td><td>8.21</td></tr><tr><td>516e7738bd8f735ac19a010ee5450d8d</td><td>e0bcbf50b9afa71ee130b94dfe8bcf2e</td><td>9d12ef1a7eca3ec58c545c678af7869c</td><td>495d4e95a8cf8bbf8b432b612a2aa328</td><td>2018-05-08 13:32:34</td><td>health_beauty</td><td>online_small</td><td>cat</td><td>null</td><td>null</td><td>null</td><td>reseller</td><td>null</td><td>0.0</td><td>00345f338696283410b7977d2e3efc89</td><td>1</td><td>0f2fd0a589cb7849c1dbedbd4109c2f8</td><td>2018-08-23 15:11:40</td><td>48.90</td><td>18.44</td></tr><tr><td>c54679b132454625907c773d273d4126</td><td>428a96d781ccb96d757bbf82f8242d95</td><td>068066e24f0c643eb1d089c7dd20cd73</td><td>4ef15afb4b2723d8f3d81e51ec7afefe</td><td>2018-01-08 19:14:47</td><td>health_beauty</td><td>online_medium</td><td>null</td><td>null</td><td>null</td><td>null</td><td>manufacturer</td><td>null</td><td>0.0</td><td>003822434f91204da0a51fe4cf2aba18</td><td>1</td><td>99e71b776debf2f01a69dce207e3e4f8</td><td>2018-06-21 02:30:28</td><td>69.00</td><td>18.58</td></tr><tr><td>c54679b132454625907c773d273d4126</td><td>428a96d781ccb96d757bbf82f8242d95</td><td>068066e24f0c643eb1d089c7dd20cd73</td><td>4ef15afb4b2723d8f3d81e51ec7afefe</td><td>2018-01-08 19:14:47</td><td>health_beauty</td><td>online_medium</td><td>null</td><td>null</td><td>null</td><td>null</td><td>manufacturer</td><td>null</td><td>0.0</td><td>003822434f91204da0a51fe4cf2aba18</td><td>2</td><td>99e71b776debf2f01a69dce207e3e4f8</td><td>2018-06-21 02:30:28</td><td>69.00</td><td>18.58</td></tr><tr><td>7d13fca15225358621be ...

# %%
data = data.join(orders, on= ['order_id'], how='inner')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data = data.join(products, on= ['product_id'], how='inner')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data = data.join(product_translation, on= ['product_category_name'], how='left')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(data.count(), len(data.columns))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">5044 36
# </div>

# %%
data = data[data['order_status'] == 'delivered']
print(data.count(), len(data.columns))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">4984 36
# </div>

# %%
data['order_purchase_timestamp']
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_category_name</th><th>product_id</th><th>order_id</th><th>seller_id</th><th>mql_id</th><th>sdr_id</th><th>sr_id</th><th>won_date</th><th>business_segment</th><th>lead_type</th><th>lead_behaviour_profile</th><th>has_company</th><th>has_gtin</th><th>average_stock</th><th>business_type</th><th>declared_product_catalog_size</th><th>declared_monthly_revenue</th><th>order_item_id</th><th>shipping_limit_date</th><th>price</th><th>freight_value</th><th>customer_id</th><th>order_status</th><th>order_purchase_timestamp</th><th>order_approved_at</th><th>order_delivered_carrier_date</th><th>order_delivered_customer_date</th><th>order_estimated_delivery_date</th><th>product_name_lenght</th><th>product_description_lenght</th><th>product_photos_qty</th><th>product_weight_g</th><th>product_length_cm</th><th>product_height_cm</th><th>product_width_cm</th><th>product_category_name_english</th></tr></thead><tbody><tr><td>automotivo</td><td>c0fc7711dd6c18600d83a5420d0e010b</td><td>12052ac6aa067434388199224c0f11bc</td><td>7ff588a03c2aeae4fbd23f9ae64b760d</td><td>d0b16c2b9e945575082a7e81f6f933b0</td><td>370c9f455f93a9a96cbe9bea48e70033</td><td>de63de0d10a6012430098db33
reseller</td><td>null</td><td>0.0</td><td>1</td><td>2018-03-16 09:55:29</td><td>178.99</td><td>13.69</td><td>9925489a4232af07111f26db403ec8fe</td><td>delivered</td><td>2018-03-12T09:38:11.000+0000</td><td>2018-03-12T09:55:29.000+0000</td><td>2018-03-15T00:08:48.000+0000</td><td>2018-04-05T23:56:40.000+0000</td><td>2018-03-28T00:00:00.000+0000</td><td>59</td><td>1088</td><td>2</td><td>292</td><td>17</td><td>8</td><td>12</td><td>watches_gifts</td><td>2018-03-12</td></tr><tr><td>utilidades_domesticas</td><td>72bb19eb8886399d5a46785146792ba7</td><td>51491c23fabcfdfc4950c9073911b993</td><td>138dbe45fc62f1e244378131a6801526</td><td>22c0b2a19a05fff19e92fab5a0b7728b</td><td>9d12ef1a7eca3ec58c545c678af7869c</td><td>9e4d1098a3b0f5da39b0bc48f9876645</td><td>2018-04-25 17:19:34</td><td>household_utilities</td><td>online_mediu ...

# %%
# What is the purpose of this line? It is not working!
cols = data.groupby('business_segment')
# display(cols)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# What is the purpose of this line? It is not working!
monthly_segment_revenue = data.groupby(['order_purchase_timestamp(y-m)', 'business_segment'])
#display(monthly_segment_revenue)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
watches = data[data.business_segment == 'watches']
print(watches.count(), len(watches.columns))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">586 37
# </div>

# %%
# What is the purpose of this line? It is not working!
cols = watches.groupby('product_category_name_english')
#display(cols)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# What is the purpose of this line? It is not working!
monthly_revenue_category = watches.groupby(['order_purchase_timestamp(y-m)', 'product_category_name_english'])
#display(monthly_revenue_category)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create 'seller - product category' table
# What is the purpose of this line? It is not working!
cols = watches.groupby('product_category_name_english')
#display(cols)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# What is the purpose of this line? It is not working!
watches_seller_revenue = watches.groupby(['seller_id', 'product_category_name_english'])
#display(watches_seller_revenue)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create 'category - seller' table
# What is the purpose of this line? It is not working!
index = watches.groupby('product_category_name_english')
#display(index)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# What is the purpose of this line? It is not working!
seller_category_revenue = watches.groupby(['seller_id', 'product_category_name_english'])
#display(seller_category_revenue)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create seller info table
# What is the purpose of this line? It is not working!
seller_ids = watches.groupby('seller_id').price.sum().index
#display(seller_ids)
fields = ['seller_id', 'won_date', 'business_segment', 'lead_type','business_type',]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansigreen">&lt;command-1800894060539698&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      1</span> <span class="ansired"># Create seller info table</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> <span class="ansired"># What is the purpose of this line? It is not working!</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 3</span><span class="ansiyellow"> </span>seller_ids <span class="ansiyellow">=</span> watches<span class="ansiyellow">.</span>groupby<span class="ansiyellow">(</span><span class="ansiblue">&apos;seller_id&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">.</span>price<span class="ansiyellow">.</span>sum<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow">.</span>index<span class="ansiyellow"></span>
# <span class="ansigreen">      4</span> <span class="ansired">#display(seller_ids)</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">      5</span> fields <span class="ansiyellow">=</span> <span class="ansiyellow">[</span><span class="ansiblue">&apos;seller_id&apos;</span><span class="ansiyellow">,</span> <span class="ansiblue">&apos;won_date&apos;</span><span class="ansiyellow">,</span> <span class="ansiblue">&apos;business_segment&apos;</span><span class="ansiyellow">,</span> <span class="ansiblue">&apos;lead_type&apos;</span><span class="ansiyellow">,</span><span class="ansiblue">&apos;business_type&apos;</span><span class="ansiyellow">,</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
#
# <span class="ansired">AttributeError</span>: &apos;GroupedData&apos; object has no attribute &apos;price&apos;</div>
